# %% [markdown]
# # **DATA ANALYTICS AND VISUALIZATION : LAB 01**

# %% [markdown]
# ## **Aim**: Getting introduced to data analytics libraries in Python and R

# %% [markdown]
# ## **Task to be performed**: Explore five libraries in each Python and R.
#
# Python libraries: pandas, numpy, scikit-learn, seaborn, matplotlib
#
# R libraries: dplyr, tidyr, readr, stringr, ggplot2

# %% [markdown]
# ## **Python**

# %% [markdown]
# Importing modules

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()
iris["data"][:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
df = pd.DataFrame(data=iris["data"], columns=iris["feature_names"])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# Importing dataset

# %%
df['sepal length (cm)'].plot(kind='hist', bins=20, title='sepal length (cm)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['sepal width (cm)'].plot(kind='hist', bins=20, title='sepal width (cm)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['petal length (cm)'].plot(kind='hist', bins=20, title='petal length (cm)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
sns.set_theme()
tips = sns.load_dataset('tips')
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %% [markdown]
# ## **R**

# %%
library(dplyr)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
mydata = read.csv("https://raw.githubusercontent.com/deepanshu88/data/master/sampledata.csv")

# %%
sample_n(mydata,3)
# Out:
#   Index State       Y2002   Y2003   Y2004   Y2005   Y2006   Y2007   Y2008
# 1 M     Mississippi 1983285 1292558 1631325 1943311 1354579 1731643 1428291
# 2 W     Washington  1977749 1687136 1199490 1163092 1334864 1621989 1545621
# 3 W     Wisconsin   1788920 1518578 1289663 1436888 1251678 1721874 1980167
#   Y2009   Y2010   Y2011   Y2012   Y2013   Y2014   Y2015
# 1 1568049 1383227 1629132 1988270 1907777 1649668 1991232
# 2 1555554 1179331 1150089 1775787 1273834 1387428 1377341
# 3 1901394 1648755 1940943 1729177 1510119 1701650 1846238

# %%
sample_frac(mydata,0.1)
# Out:
#   Index State        Y2002   Y2003   Y2004   Y2005   Y2006   Y2007   Y2008
# 1 I     Iowa         1499269 1444576 1576367 1388924 1554813 1452911 1317983
# 2 C     Colorado     1343824 1878473 1886149 1236697 1871471 1814218 1875146
# 3 M     Montana      1877154 1540099 1332722 1273327 1625721 1983568 1251742
# 4 T     Texas        1520591 1310777 1957713 1907326 1873544 1655483 1785986
# 5 N     North Dakota 1618807 1510193 1876940 1443172 1425030 1868788 1720352
#   Y2009   Y2010   Y2011   Y2012   Y2013   Y2014   Y2015
# 1 1150783 1751389 1992996 1501879 1173694 1431705 1641866
# 2 1752387 1913275 1665877 1491604 1178355 1383978 1330736
# 3 1592690 1350619 1520064 1185225 1465705 1110394 1125903
# 4 1827503 1447457 1978374 1882532 1698698 1646508 1705322
# 5 1671468 1534571 1271132 1430978 1529024 1563898 1604118

# %%
data("midwest", package = "ggplot2")

# %%
g <- ggplot(midwest, aes(x=area, y=poptotal)) + geom_point() + geom_smooth(method="lm")  # set se=FALSE to turnoff confidence bands

g1 <- g + coord_cartesian(xlim=c(0,0.1), ylim=c(0, 1000000))  # zooms in

# Add Title and Labels
g1 + labs(title="Area Vs Population", subtitle="From midwest dataset", y="Population", x="Area", caption="Midwest Demographics")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
gg <- ggplot(midwest, aes(x=area, y=poptotal)) +
  geom_point(aes(col=state), size=3) +  # Set color to vary based on state categories.
  geom_smooth(method="lm", col="firebrick", size=2) +
  coord_cartesian(xlim=c(0, 0.1), ylim=c(0, 1000000)) +
  labs(title="Area Vs Population", subtitle="From midwest dataset", y="Population", x="Area", caption="Midwest Demographics")

gg <- gg + scale_x_continuous(breaks=seq(0, 0.1, 0.01))

# method 1: Using theme_set()
theme_set(theme_classic())  # not run
gg
# Out:
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# ## **Outcome**:
# 1. Identified the Data Analytics Libraries in Python and R
# 2. Performed simple experiments with these libraries in Python and R
