# %% [markdown]
# # **DATA ANALYTICS AND VISUALIZATION : LAB 02**

# %% [markdown]
# ## **Aim:**
# Simple Linear Regression in Python and R

# %% [markdown]
# ## **Tasks to be performed:**
#
#
#
# 1. List the packages to be used for Simple Linear Regression in Python
# 2. Download the dataset from UCI Repository / Kaggle -- Load data into Google Colab -- Display the summary of the dataset
# 3. Check whether the data meets the assumptions -- Normality : Check whether the dependent variable follows a normal distribution -- Lineartiy : Check the relationship between the independent and dependent variable
# 4. Perform Linear Regression Analysis using the identified package
# 5. Visualize the results with a graph -- Draw the Simple Linear Regression line to the plotted data -- Add the equation for the Regression Line on the graph
# 6. Repeat the steps 2 to 5 using R libraries
# 7. Prepare a document with the Aim, Tasks performed, Program, Output, and Conclusion.

# %% [markdown]
# ## **Program:**

# %% [markdown]
# ### Python

# %% [markdown]
# Importing libraries

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn

from sklearn.linear_model import LinearRegression

# %% [markdown]
# Downloading datasets from [here](https://www.kaggle.com/datasets/andonians/random-linear-regression).

# %%
train = pd.read_csv("/content/train.csv")
test = pd.read_csv("/content/test.csv")

# %%
train.dropna(how="any", inplace=True)
test.dropna(how="any", inplace=True)

# %% [markdown]
# EDA for the data

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       699 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 16.4 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       300 non-null    int64
#  1   y       300 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 4.8 KB

# %%
X_train = train[["x"]]
y_train = train[["y"]]

# %%
X_test = test[["x"]]
y_test = test[["y"]]

# %%
plt.scatter(x=X_train, y=y_train)
plt.show()

# %% [markdown]
# Creating a simple linear regression model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Reviewing model

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_train, y_train, color='lightblue')
plt.scatter(X_test, y_test, color='orange')
plt.plot(X_test, y_pred)
plt.show()

# %%
model.score(X_test, y_test)*100
# Out:
# 98.88014444327563

# %% [markdown]
# ### R

# %% [markdown]
# Importing libraries

# %% [markdown]
# Importing datasets

# %%
train = read.csv('/content/train.csv', header=TRUE, stringsAsFactors=FALSE)
test = read.csv('/content/test.csv', header=TRUE, stringsAsFactors=FALSE)

# %%
train = na.omit(train)
test = na.omit(test)

# %%
head(train)
# Out:
#   x  y
# 1 24 21.54945
# 2 50 47.46446
# 3 15 17.21866
# 4 38 36.58640
# 5 87 87.28898
# 6 36 32.46387

# %%
X_train = train[["x"]]
y_train = train[["y"]]

# %%
X_test = test[["x"]]
y_test = test[["y"]]

# %%
print(class(X_train))
print(class(y_train))
# Out:
# [1] "numeric"
# [1] "numeric"

# %% [markdown]
# Visualizing datasets

# %%
scatter.smooth(X_train, y_train)
# Out:
# plot without title

# %% [markdown]
# Creating model

# %%
model = lm(y_train ~ X_train)

# %% [markdown]
# Reviewing model

# %%
plot(X_train, y_train)
abline(model, col="red")
# Out:
# plot without title

# %% [markdown]
# ## **Output:**

# %% [markdown]
# The simple linear regresssion model was fairly good in both of the languages.

# %% [markdown]
# ## **Conclusion:**

# %% [markdown]
# We have successfully performed Simple Linear Regression in both Python and R

# %% [markdown]
# ## **Acknowledgements:**

# %% [markdown]
# 1. [Kaggle Dataset](https://www.kaggle.com/datasets/andonians/random-linear-regression)
# 2. [R Simple Linear Regression Tutorial](https://www.statology.org/simple-linear-regression-in-r/)
